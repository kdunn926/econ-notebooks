# %% [markdown]
# # What do these charts say about the economy?

# %% [markdown]
# I'll admit, the title is designed to be clickbait; I'm neither an authority on economic matters or a news anchor.
#
# Despite this, a recent rewatch of Michael Lewis' 2015 film The Big Short inspired me to use some of my funemployment free time to challenge several popular assumptions. If you have not seen the film already, it's time well-spent.
#
# So here's what I wanted to know:
#
# **_1. How does productivity of the U.S. workforce today compare to the past?_**
#
# **_2. How accurate is the official U.S. Gross Domestic Product (GDP) measure?_**
#
# **_3. How strong is the U.S. dollar, given it's value is ultimately backed by U.S. GDP?_**
#
# Whether you're a casual observer or in-the-weeds quant, the strength of the U.S. economy has an impact on both your current and future livelihood in some way.
#
# The following work is an effort to move beyond "expert opinions" and let data do the talking. I've attempted to appeal to those of us without a job in finance (and a Bloomberg terminal.)
#
# All the data sources used are public and the Python code used to for the charts is provided in the appendix.

# %% [markdown]
# #### U.S. Workforce

# %%
from IPython.display import SVG, HTML, display

display(SVG("""<svg class="marks" width="902" height="552" viewBox="0 0 902 552" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><clipPath id="clip1"><rect x="0" y="0" width="800" height="500"></rect></clipPath><clipPath id="clip2"><rect x="0" y="0" width="800" height="500"></rect></clipPath></defs><g transform="translate(35,29)"><g class="mark-group role-frame root"><g transform="translate(0,0)"><path class="background" d="M0.5,0.5h800v500h-800Z" style="fill: none; stroke: #ddd;"></path><g><g class="mark-rule role-mark layer_0_marks" clip-path="url(#clip1)"><line transform="translate(0,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(0.9507379720145678,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(1.8708069771899558,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(2.8215449492045237,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(3.7416139543799116,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(4.69235192639448,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(5.643089898409047,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(6.532489936745256,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(7.483227908759823,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(8.403296913935211,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(9.35403488594978,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(10.274103891125169,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(11.224841863139735,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(12.175579835154302,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(13.095648840329691,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(14.046386812344258,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(14.966455817519646,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(15.917193789534215,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(16.867931761548782,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(17.72666283304581,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(18.67740080506038,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(19.59746981023577,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(20.548207782250337,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(21.468276787425726,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(22.41901475944029,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(23.36975273145486,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(24.289821736630245,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(25.240559708644817,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(26.160628713820206,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(27.11136668583477,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(28.06210465784934,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(28.92083572934637,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(29.871573701360937,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(30.791642706536326,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(31.74238067855089,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(32.66244968372628,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(33.613187655740845,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(34.56392562775542,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(35.4839946329308,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(36.43473260494537,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(37.35480161012076,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(38.30553958213533,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(39.2562775541499,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(40.11500862564692,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(41.06574659766149,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(41.98581560283688,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(42.93655357485145,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(43.85662258002683,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(44.8073605520414,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(45.758098524055974,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(46.67816752923136,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(47.628905501245924,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(48.54897450642132,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(49.49971247843588,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(50.45045045045045,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(51.33985048878665,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(52.290588460801224,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(53.21065746597662,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(54.161395437991175,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(55.081464443166574,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(56.032202415181146,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(56.982940387195704,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(57.9030093923711,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(58.85374736438567,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(59.77381636956105,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(60.72455434157562,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(61.67529231359019,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(62.53402338508721,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(63.48476135710178,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(64.40483036227717,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(65.35556833429173,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(66.27563733946712,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(67.22637531148169,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(68.17711328349625,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(69.09718228867166,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(70.04792026068621,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(70.9679892658616,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(71.91872723787618,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(72.86946520989073,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(73.72819628138777,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(74.67893425340235,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate(75.59900325857772,0)" x2="0" y2="500" style="fill: none; stroke: lightgray; stroke-width: 5;"></line><line transform="translate
15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1970</text><text text-anchor="middle" transform="translate(307.15864800971184,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1975</text><text text-anchor="middle" transform="translate(363.1601814580538,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1980</text><text text-anchor="middle" transform="translate(419.1923838732349,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1985</text><text text-anchor="middle" transform="translate(475.1939173215769,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1990</text><text text-anchor="middle" transform="translate(531.1954507699188,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1995</text><text text-anchor="middle" transform="translate(587.1969842182608,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2000</text><text text-anchor="middle" transform="translate(643.2291866334419,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2005</text><text text-anchor="middle" transform="translate(699.2307200817839,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2010</text><text text-anchor="middle" transform="translate(755.2322535301258,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2015</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,0)" x2="800" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g></g></g></g><g class="mark-group role-axis"><g transform="translate(0.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g></g></g></g><g class="mark-group role-axis"><g transform="translate(800.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(0,500)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,469)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,438)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,406)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,375)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,344)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,313)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,281)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,250)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,219)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,188)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,156)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,125)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,94)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,63)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,31)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,0)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(7,503)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00000</text><text text-anchor="start" transform="translate(7,471.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00005</text><text text-anchor="start" transform="translate(7,440.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00010</text><text text-anchor="start" transform="translate(7,409.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00015</text><text text-anchor="start" transform="translate(7,378)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00020</text><text text-anchor="start" transform="translate(7,346.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00025</text><text text-anchor="start" transform="translate(7,315.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00030</text><text text-anchor="start" transform="translate(7,284.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00035</text><text text-anchor="start" transform="translate(7,253)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00040</text><text text-anchor="start" transform="translate(7,221.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00045</text><text text-anchor="start" transform="translate(7,190.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00050</text><text text-anchor="start" transform="translate(7,159.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00055</text><text text-anchor="start" transform="translate(7,128.00000000000006)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00060</text><text text-anchor="start" transform="translate(7,96.75000000000006)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00065</text><text text-anchor="start" transform="translate(7,65.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00070</text><text text-anchor="start" transform="translate(7,34.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00075</text><text text-anchor="start" transform="translate(7,3)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00080</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(48.1474609375,250) rotate(90) translate(0,-2)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">Specific economic output [$]</text></g></g></g></g></g></g></g></g></svg>"""))

# %% [markdown]
# This chart shows that the workforce efficiency tends to rise during economic recessions (shaded in grey). It seems **roughly half of the post-2008 stimulus effect remains**. Technological improvements might deserve the credit for an overall upward trend since the late 1940s.  Each hour worked should produce more economic value today than in the past.
#
# There is a catch though, the "Real Output per Hour" data is adjusted to a 2009 base year in an undocumented way. In the spirit of transparency I wanted to reproduce the chart using the _source data directly_, conveniently cited by FRED.

# %%
display(SVG("""<svg class="marks" width="902" height="552" viewBox="0 0 902 552" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g transform="translate(35,29)"><g class="mark-group role-frame root"><g transform="translate(0,0)"><path class="background" d="M0.5,0.5h800v500h-800Z" style="fill: none; stroke: #ddd;"></path><g><g class="mark-rule role-mark layer_0_marks"><line transform="translate(0,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(0.9507379720145678,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(1.8708069771899558,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(2.8215449492045237,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(3.7416139543799116,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(4.69235192639448,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(5.643089898409047,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(6.532489936745256,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(7.483227908759823,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(8.403296913935211,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate(9.35403488594978,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 1;"></line><line transform="translate
title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(415.57373046875,-13)" style="font-family: sans-serif; font-size: 13px; font-weight: bold; fill: #000; opacity: 1;">U.S. Real Output per Hour per Employee (Nonfarm) over Time</text></g><g class="mark-group role-axis"><g transform="translate(0.5,500.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(27,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(83,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(139,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(195,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(251,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(307,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(363,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(419,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(475,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(531,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(587,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(643,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(699,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(755,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="middle" transform="translate(27.120311801162867,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1950</text><text text-anchor="middle" transform="translate(83.12184524950482,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1955</text><text text-anchor="middle" transform="translate(139.1233786978468,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1960</text><text text-anchor="middle" transform="translate(195.15558111302792,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1965</text><text text-anchor="middle" transform="translate(251.1571145613699,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1970</text><text text-anchor="middle" transform="translate(307.15864800971184,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1975</text><text text-anchor="middle" transform="translate(363.1601814580538,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1980</text><text text-anchor="middle" transform="translate(419.1923838732349,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1985</text><text text-anchor="middle" transform="translate(475.1939173215769,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1990</text><text text-anchor="middle" transform="translate(531.1954507699188,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1995</text><text text-anchor="middle" transform="translate(587.1969842182608,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2000</text><text text-anchor="middle" transform="translate(643.2291866334419,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2005</text><text text-anchor="middle" transform="translate(699.2307200817839,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2010</text><text text-anchor="middle" transform="translate(755.2322535301258,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2015</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,0)" x2="800" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g></g></g></g><g class="mark-group role-axis"><g transform="translate(0.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g></g></g></g><g class="mark-group role-axis"><g transform="translate(800.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(0,500)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,469)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,438)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,406)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,375)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,344)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,313)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,281)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,250)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,219)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,188)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,156)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,125)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,94)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,63)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,31)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,0)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(7,503)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00000</text><text text-anchor="start" transform="translate(7,471.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00005</text><text text-anchor="start" transform="translate(7,440.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00010</text><text text-anchor="start" transform="translate(7,409.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00015</text><text text-anchor="start" transform="translate(7,378)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00020</text><text text-anchor="start" transform="translate(7,346.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00025</text><text text-anchor="start" transform="translate(7,315.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00030</text><text text-anchor="start" transform="translate(7,284.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00035</text><text text-anchor="start" transform="translate(7,253)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00040</text><text text-anchor="start" transform="translate(7,221.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00045</text><text text-anchor="start" transform="translate(7,190.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00050</text><text text-anchor="start" transform="translate(7,159.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00055</text><text text-anchor="start" transform="translate(7,128.00000000000006)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00060</text><text text-anchor="start" transform="translate(7,96.75000000000006)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00065</text><text text-anchor="start" transform="translate(7,65.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00070</text><text text-anchor="start" transform="translate(7,34.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00075</text><text text-anchor="start" transform="translate(7,3)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00080</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(48.1474609375,250) rotate(90) translate(0,-2)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">Specific economic output [$]</text></g></g></g></g><g class="mark-group role-axis"><g transform="translate(800.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(0,500)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,469)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,438)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,406)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,375)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,344)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,313)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,281)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,250)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,219)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,188)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,156)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,125)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,94)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,63)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,31)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,0)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(7,503)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00000</text><text text-anchor="start" transform="translate(7,471.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00005</text><text text-anchor="start" transform="translate(7,440.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00010</text><text text-anchor="start" transform="translate(7,409.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00015</text><text text-anchor="start" transform="translate(7,378)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00020</text><text text-anchor="start" transform="translate(7,346.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00025</text><text text-anchor="start" transform="translate(7,315.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00030</text><text text-anchor="start" transform="translate(7,284.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00035</text><text text-anchor="start" transform="translate(7,253)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00040</text><text text-anchor="start" transform="translate(7,221.75)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00045</text><text text-anchor="start" transform="translate(7,190.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00050</text><text text-anchor="start" transform="translate(7,159.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00055</text><text text-anchor="start" transform="translate(7,128.00000000000006)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00060</text><text text-anchor="start" transform="translate(7,96.75000000000006)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00065</text><text text-anchor="start" transform="translate(7,65.5)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00070</text><text text-anchor="start" transform="translate(7,34.25)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00075</text><text text-anchor="start" transform="translate(7,3)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00080</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(48.1474609375,250) rotate(90) translate(0,-2)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">Specific economic output [$]</text></g></g></g></g></g></g></g></g></svg>"""))

# %% [markdown]
# The gold line above was created using FRED's "Real GDP" data along with "Hours worked" and "Nonfarm Payroll" data, both from the Bureau of Labor Statistics (BLS). Inflationary adjustments are handled by the GDP data whereas the hours and payroll data are unmodified.
#
# I found the result quite interesting, as it tells a different story.
#
# According to the re-creation (in gold above), **nearly all of the post-2009 stimulus seems to have worn off**.  The chart also shows worker efficiency is nearly flat since the late 1940s.

# %% [markdown]
# ## U.S. Workforce Efficiency and Energy Consumption
# _The data from the following charts originates from the U.S. Department of Energy, the U.S. Bureau of Economic Analysis, and the U.S. Bureau of Labor Statistics (the latter two acquired via FRED)._

# %%
display(SVG("""<svg class="marks" width="1136" height="569" viewBox="0 0 1136 569" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g transform="translate(67,29)"><g class="mark-group role-frame root"><g transform="translate(0,0)"><path class="background" d="M0.5,0.5h1000v500h-1000Z" style="fill: none; stroke: #ddd;"></path><g><g class="mark-group role-axis"><g transform="translate(0.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-grid" style="pointer-events: none;"><line transform="translate(0,500)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,472)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,444)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,417)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,389)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,361)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,333)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,306)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,278)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,250)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,222)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,194)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,167)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,139)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,111)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,83)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,56)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,28)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,0)" x2="1000" y2="0" style="fill: none; stroke: #ddd; stroke-width: 1; opacity: 1;"></line></g></g></g></g><g class="mark-symbol role-mark layer_0_marks"><path transform="translate(86.58050923076924,399.1669398537113)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(124.61773076923077,333.34618845593326)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(125.66574923076924,298.7041528168946)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(201.12487384615386,353.41541033353707)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(257.35605153846154,413.14797089015406)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(317.91275,435.5236086622401)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(385.4823323076923,451.41904402802123)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(419.70033076923073,476.91740943449946)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(510.94673,477.5815463561491)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(547.7592946153846,475.2181204421285)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(631.85712,466.0150959066764)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(611.1216207692308,384.1677265327984)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(665.7430853846154,327.26938422240096)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(687.4880753846154,246.04662706069075)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(728.8303684615385,251.33061028751254)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(816.1296315384615,269.9010698044508)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 2; opacity: 0.7;"></path><path transform="translate(823.0144938461539,288.5283665879272)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 2; opacity: 0.7;"></path><path transform="translate
15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 0;">3,650,000,000</text><text text-anchor="middle" transform="translate(846.1538461538462,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 0;">3,700,000,000</text><text text-anchor="middle" transform="translate(884.6153846153845,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 0;">3,750,000,000</text><text text-anchor="middle" transform="translate(923.0769230769231,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,800,000,000</text><text text-anchor="middle" transform="translate(961.5384615384615,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 0;">3,850,000,000</text><text text-anchor="end" transform="translate(1000,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 0;">3,900,000,000</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,0)" x2="1000" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(500,31)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">Megawatt-hours</text></g></g></g></g><g class="mark-group role-axis"><g transform="translate(0.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(0,500)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,472)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,444)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,417)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,389)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,361)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,333)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,306)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,278)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,250)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,222)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,194)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,167)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,139)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,111)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,83)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,56)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,28)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,0)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="end" transform="translate(-7,503)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00054</text><text text-anchor="end" transform="translate(-7,475.2222222222222)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00055</text><text text-anchor="end" transform="translate(-7,447.4444444444446)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00056</text><text text-anchor="end" transform="translate(-7,419.66666666666674)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00057</text><text text-anchor="end" transform="translate(-7,391.8888888888889)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00058</text><text text-anchor="end" transform="translate(-7,364.1111111111111)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00059</text><text text-anchor="end" transform="translate(-7,336.33333333333354)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00060</text><text text-anchor="end" transform="translate(-7,308.55555555555566)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00061</text><text text-anchor="end" transform="translate(-7,280.7777777777778)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00062</text><text text-anchor="end" transform="translate(-7,253)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00063</text><text text-anchor="end" transform="translate(-7,225.22222222222217)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00064</text><text text-anchor="end" transform="translate(-7,197.44444444444457)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00065</text><text text-anchor="end" transform="translate(-7,169.66666666666674)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00066</text><text text-anchor="end" transform="translate(-7,141.8888888888889)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00067</text><text text-anchor="end" transform="translate(-7,114.11111111111109)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00068</text><text text-anchor="end" transform="translate(-7,86.33333333333354)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00069</text><text text-anchor="end" transform="translate(-7,58.55555555555571)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00070</text><text text-anchor="end" transform="translate(-7,30.77777777777783)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00071</text><text text-anchor="end" transform="translate(-7,3)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00072</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(-48.1474609375,250) rotate(-90) translate(0,-2)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">Real output per hour per employee</text></g></g></g></g></g></g></g></g></svg>"""))

# %% [markdown]
# We can look further under the hood of the economy by charting the electricity it consumes.
#
# The chart above suggests very different trends in each of the decades, starting in 1990. The downward trend during the 1990s shows more electricity was used yet workforce productivity declined overall. The trend reversed in the decade following the "dot com" boom.
#
# The decade following 2008 tells us some interesting points:
# - Between 2008 and 2009, efficiency jumped about 10%, while electricity usage fell.
# - Since 2009, electricity usage has changed very little, while efficiency has dropped below 2008 levels.
#
# If the trend continues, **productivity will be nearly the same as 1992, yet electricity usage will be almost 25% higher**.

# %%
display(SVG("""<svg class="marks" width="1163" height="569" viewBox="0 0 1163 569" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g transform="translate(94,29)"><g class="mark-group role-frame root"><g transform="translate(0,0)"><path class="background" d="M0.5,0.5h1000v500h-1000Z" style="fill: none; stroke: #ddd;"></path><g><g class="mark-symbol role-mark layer_0_marks"><path transform="translate(90.73630000000011,456.70974538461536)" d="M2.7386127875258306,0A2.7386127875258306,2.7386127875258306,0,1,1,-2.7386127875258306,0A2.7386127875258306,2.7386127875258306,0,1,1,2.7386127875258306,0" style="fill: none; stroke: #4c78a8; stroke-width: 2; opacity: 0.7;"></path><path transform="translate
" style="font-family: sans-serif; font-size: 10px; fill: #e45756;">2014</text><text text-anchor="start" transform="translate(861.7618999999999,57.23369517692328)" style="font-family: sans-serif; font-size: 10px; fill: #e45756;">2015</text><text text-anchor="start" transform="translate(892.1419999999998,55.89937398076978)" style="font-family: sans-serif; font-size: 10px; fill: #e45756;">2016</text><text text-anchor="start" transform="translate(935.6496999999999,86.84823573461512)" style="font-family: sans-serif; font-size: 10px; fill: #e45756;">2017</text></g><g class="mark-group role-legend"><g transform="translate(1018,0)"><path class="background" d="M0,0h46v61h-46Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-group role-legend-entry"><g transform="translate(0,16)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-group role-scope"><g transform="translate(0,0)"><path class="background" d="M0,0h46.1552734375v12.5h-46.1552734375Z" style="pointer-events: none; fill: none; opacity: 1;"></path><g><g class="mark-symbol role-legend-symbol" style="pointer-events: none;"><path transform="translate(6,6)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #4c78a8; stroke-width: 1.5; opacity: 0.7;"></path></g><g class="mark-text role-legend-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(16,9)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1990's</text></g></g></g><g transform="translate(0,16)"><path class="background" d="M0,0h46.1552734375v12.5h-46.1552734375Z" style="pointer-events: none; fill: none; opacity: 1;"></path><g><g class="mark-symbol role-legend-symbol" style="pointer-events: none;"><path transform="translate(6,6)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #f58518; stroke-width: 1.5; opacity: 0.7;"></path></g><g class="mark-text role-legend-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(16,9)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2000's</text></g></g></g><g transform="translate(0,32)"><path class="background" d="M0,0h46.1552734375v12.5h-46.1552734375Z" style="pointer-events: none; fill: none; opacity: 1;"></path><g><g class="mark-symbol role-legend-symbol" style="pointer-events: none;"><path transform="translate(6,6)" d="M5,0A5,5,0,1,1,-5,0A5,5,0,1,1,5,0" style="fill: none; stroke: #e45756; stroke-width: 1.5; opacity: 0.7;"></path></g><g class="mark-text role-legend-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(16,9)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2010's</text></g></g></g></g></g></g></g><g class="mark-text role-legend-title" style="pointer-events: none;"><text text-anchor="start" transform="translate(0,9)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">decade</text></g></g></g></g><g class="mark-text role-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(487.52490234375,-13)" style="font-family: sans-serif; font-size: 13px; font-weight: bold; fill: #000; opacity: 1;">Total Electricity Consumption vs U.S. Real Gross Domestic Product</text></g><g class="mark-group role-axis"><g transform="translate(0.5,500.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(0,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(50,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(100,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(150,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(200,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(250,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(300,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(350,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(400,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(450,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(500,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(550,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(600,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(650,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(700,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(750,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(800,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(850,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(900,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(950,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(1000,0)" x2="0" y2="5" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(0,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">8,000</text><text text-anchor="middle" transform="translate(50,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">8,500</text><text text-anchor="middle" transform="translate(100,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">9,000</text><text text-anchor="middle" transform="translate(150,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">9,500</text><text text-anchor="middle" transform="translate(200,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">10,000</text><text text-anchor="middle" transform="translate(250,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">10,500</text><text text-anchor="middle" transform="translate(300,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">11,000</text><text text-anchor="middle" transform="translate(350,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">11,500</text><text text-anchor="middle" transform="translate(400,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">12,000</text><text text-anchor="middle" transform="translate(450,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">12,500</text><text text-anchor="middle" transform="translate(500,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">13,000</text><text text-anchor="middle" transform="translate(550,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">13,500</text><text text-anchor="middle" transform="translate(600,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">14,000</text><text text-anchor="middle" transform="translate(650,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">14,500</text><text text-anchor="middle" transform="translate(700,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">15,000</text><text text-anchor="middle" transform="translate(750,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">15,500</text><text text-anchor="middle" transform="translate(800,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">16,000</text><text text-anchor="middle" transform="translate(850,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">16,500</text><text text-anchor="middle" transform="translate(900,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">17,000</text><text text-anchor="middle" transform="translate(950,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">17,500</text><text text-anchor="end" transform="translate(1000,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">18,000</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,0)" x2="1000" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(500,31)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">GDP</text></g></g></g></g><g class="mark-group role-axis"><g transform="translate(0.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(0,500)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,462)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,423)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,385)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,346)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,308)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,269)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,231)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,192)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,154)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,115)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,77)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,38)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,0)" x2="-5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="end" transform="translate(-7,503)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2,600,000,000</text><text text-anchor="end" transform="translate(-7,464.53846153846155)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2,700,000,000</text><text text-anchor="end" transform="translate(-7,426.0769230769231)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2,800,000,000</text><text text-anchor="end" transform="translate(-7,387.61538461538464)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2,900,000,000</text><text text-anchor="end" transform="translate(-7,349.15384615384613)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,000,000,000</text><text text-anchor="end" transform="translate(-7,310.6923076923077)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,100,000,000</text><text text-anchor="end" transform="translate(-7,272.2307692307692)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,200,000,000</text><text text-anchor="end" transform="translate(-7,233.76923076923077)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,300,000,000</text><text text-anchor="end" transform="translate(-7,195.30769230769226)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,400,000,000</text><text text-anchor="end" transform="translate(-7,156.84615384615387)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,500,000,000</text><text text-anchor="end" transform="translate(-7,118.38461538461536)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,600,000,000</text><text text-anchor="end" transform="translate(-7,79.9230769230769)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,700,000,000</text><text text-anchor="end" transform="translate(-7,41.46153846153845)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,800,000,000</text><text text-anchor="end" transform="translate(-7,3)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">3,900,000,000</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(-75.9501953125,250) rotate(-90) translate(0,-2)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">Megawatt-hours</text></g></g></g></g></g></g></g></g></svg>"""))

# %% [markdown]
# Growth in economic output *should* require more energy input, even as efficiency approaches perfection (we're a long ways off).
#
# From an inputs and outputs point of view, the chart above makes the following point. **Overall since 2009, GDP has grown about 10% while electricity usage has slightly shrunk.**
#
# In high school physics classrooms, this might be restated as being a perpetual motion machine. Next door in economics 101, this looks like a free lunch. In both cases, eyebrows should raise and lead us to even more questions:
#
# - **_Has GDP been lower than reported in the most recent decade?_**
# - **_Has electricity usage been higher than reported?_**
# - **_Are both of the above true?_**

# %% [markdown]
# #### Money supply and U.S. GDP

# %%
display(SVG("""<svg class="marks" width="1087" height="552" viewBox="0 0 1087 552" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g transform="translate(35,29)"><g class="mark-group role-frame root"><g transform="translate(0,0)"><path class="background" d="M0.5,0.5h1000v500h-1000Z" style="fill: none; stroke: #ddd;"></path><g><g class="mark-rule role-mark layer_0_marks"><line transform="translate(217.09056848476115,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 3;"></line><line transform="translate(219.25210750054038,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 3;"></line><line transform="translate(221.4856978168456,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 3;"></line><line transform="translate(223.64723683262483,500)" x2="0" y2="0" style="fill: none; stroke: lightgray; stroke-width: 3;"></line><line transform="translate
15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1994</text><text text-anchor="middle" transform="translate(394.79009054446766,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1996</text><text text-anchor="middle" transform="translate(447.459591228955,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">1998</text><text text-anchor="middle" transform="translate(500.05704061291647,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2000</text><text text-anchor="middle" transform="translate(552.7265412974037,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2002</text><text text-anchor="middle" transform="translate(605.3239906813651,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2004</text><text text-anchor="middle" transform="translate(657.9934913658525,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2006</text><text text-anchor="middle" transform="translate(710.5909407498139,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2008</text><text text-anchor="middle" transform="translate(763.2604414343012,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2010</text><text text-anchor="middle" transform="translate(815.8578908182626,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2012</text><text text-anchor="middle" transform="translate(868.5273915027499,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2014</text><text text-anchor="middle" transform="translate(921.1248408867114,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2016</text><text text-anchor="middle" transform="translate(973.7943415711987,15)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">2018</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,0)" x2="1000" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g></g></g></g><g class="mark-group role-axis"><g transform="translate(0.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g></g></g></g><g class="mark-group role-axis"><g transform="translate(1000.5,0.5)"><path class="background" d="M0,0h0v0h0Z" style="pointer-events: none; fill: none;"></path><g><g class="mark-rule role-axis-tick" style="pointer-events: none;"><line transform="translate(0,500)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,472)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,444)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,417)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,389)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,361)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,333)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,306)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,278)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,250)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,222)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,194)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,167)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,139)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,111)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,83)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,56)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,28)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line><line transform="translate(0,0)" x2="5" y2="0" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-label" style="pointer-events: none;"><text text-anchor="start" transform="translate(7,503)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.00</text><text text-anchor="start" transform="translate(7,475.22222222222223)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.05</text><text text-anchor="start" transform="translate(7,447.44444444444446)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.10</text><text text-anchor="start" transform="translate(7,419.6666666666667)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.15</text><text text-anchor="start" transform="translate(7,391.8888888888889)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.20</text><text text-anchor="start" transform="translate(7,364.1111111111111)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.25</text><text text-anchor="start" transform="translate(7,336.33333333333337)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.30</text><text text-anchor="start" transform="translate(7,308.55555555555554)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.35</text><text text-anchor="start" transform="translate(7,280.77777777777777)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.40</text><text text-anchor="start" transform="translate(7,253)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.45</text><text text-anchor="start" transform="translate(7,225.22222222222223)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.50</text><text text-anchor="start" transform="translate(7,197.4444444444444)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.55</text><text text-anchor="start" transform="translate(7,169.66666666666669)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.60</text><text text-anchor="start" transform="translate(7,141.8888888888889)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.65</text><text text-anchor="start" transform="translate(7,114.11111111111114)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.70</text><text text-anchor="start" transform="translate(7,86.33333333333337)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.75</text><text text-anchor="start" transform="translate(7,58.55555555555554)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.80</text><text text-anchor="start" transform="translate(7,30.77777777777777)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.85</text><text text-anchor="start" transform="translate(7,3)" style="font-family: sans-serif; font-size: 10px; fill: #000; opacity: 1;">0.90</text></g><g class="mark-rule role-axis-domain" style="pointer-events: none;"><line transform="translate(0,500)" x2="0" y2="-500" style="fill: none; stroke: #888; stroke-width: 1; opacity: 1;"></line></g><g class="mark-text role-axis-title" style="pointer-events: none;"><text text-anchor="middle" transform="translate(34,250) rotate(90) translate(0,-2)" style="font-family: sans-serif; font-size: 11px; font-weight: bold; fill: #000; opacity: 1;">M2 to GDP</text></g></g></g></g></g></g></g></g></svg>"""))

# %% [markdown]
# Don't be fooled by the underwhelming look of this chart, as the punchline is simple: **the U.S. dollar is half as strong as it was in 2000**. Said another way, the **inflation of the dollar has averaged 3.9% annually since 2000, roughly double the official number**. Each of these conclusions also assumes the Real GDP number is accurate, a tough sell given the evidence above. There's really only one explanation: quantitative easing (QE) has not generated enough economic activity (GDP) to justify the value of the dollars printed under the program.

# %% [markdown]
# ### Closing thoughts

# %% [markdown]
# When I started this effort, I could remember very little about what I had learned in economics or heard on the news regarding employment, GDP, or monetary stimulus.  Day-to-day, the impact these macro issues have is hard to observe yet the long term consequences can't be overstated.  Anyone with cash savings, a 401k/IRA retirement plan, or even simply aspirations of owning a home is impacted by these trends; they will dictate future value.
#
# Am I saying run for the hills, buy gold (or Bitcoin), or dig a prepper shelter: not necessarily.  **I am saying be skeptical to a one-sided narrative about the health of the U.S. economy, the impregnable value of the U.S. dollar (and other fiat currencies), or how record stock valuations imply either of the former.**
#
# Mainly, just remember this: _"If it's too good to be true, it probably is."_

# %% [markdown]
# ## Appendix

# %%
import pandas as pd
import numpy as np
import benford as bf

# %%
# Load the FRED API key - you may register for one here: 
# https://research.stlouisfed.org/useraccount/login/secure/
apiKey = open("/Users/kyledunn/fredApiKey.txt", "r").read().strip()

# %%
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen
    
def getSeries(series="", description=None, apiKey=apiKey):
    """
    Fetch a data series from the St. Louis FED system (FRED)
    and return it as a Pandas dataframe indexed by date
    """
    baseUrl = "https://api.stlouisfed.org"
    endpoint = "/fred/series/observations?series_id={s}&realtime_end=9999-12-31&api_key={k}&file_type=txt" 
    
    response = urlopen(baseUrl + endpoint.format(s=series, k=apiKey))
    zipfile = ZipFile(BytesIO(response.read()))
    
    filesInZip = zipfile.namelist()
    
    data = zipfile.open(filesInZip[1])

    if description is None:
        description = series
        
    df = pd.read_csv(data, sep="\t", header=None, skiprows=1,
                       names=["date", description, "rt_start", "rt_end"], na_values=".")
    
    df['date'] = pd.to_datetime(df.date)
    
    return df.set_index("date")

# %%
df_recession = getSeries("USREC", description="Recession")

# %% [markdown]
# ---

# %% [markdown]
# #### U.S. Bureau of Labor Statistics, Nonfarm Business Sector: Real Output Per Hour of All Persons [OPHNFB]
#
# https://fred.stlouisfed.org/series/OPHNFB
#
# *Units:*  Index 2009=100, Seasonally Adjusted
#
# *Frequency:*  Quarterly
#
# The Productivity and Costs release on August 7, 2003, will reflect the June 2003 benchmark revision to payroll employment. Since employment is now reported on a North American Industry Classification System (NAICS) basis, all of the historical data will be revised. Changes as a consequence of the move to NAICS should not be significant since this release carries data at high levels of aggregation.

# %%
df_real_output = getSeries("OPHNFB", description="Real Output per Hour")

# %% [markdown]
# ---

# %% [markdown]
# #### U.S. Bureau of Labor Statistics, All Employees: Total Nonfarm Payrolls [PAYEMS]
#
# https://fred.stlouisfed.org/series/PAYEMS
#
# *Units:*  Thousands of Persons, Seasonally Adjusted
#
# *Frequency:*  Monthly
#
# All Employees: Total Nonfarm, commonly known as Total Nonfarm Payroll, is a measure of the number of U.S. workers in the economy that excludes proprietors, private household employees, unpaid volunteers, farm employees, and the unincorporated self-employed. **This measure accounts for approximately 80 percent of the workers who contribute to Gross Domestic Product (GDP).**
#
# This measure provides useful insights into the current economic situation because it can represent the number of jobs added or lost in an economy. Increases in employment might indicate that businesses are hiring which might also suggest that businesses are growing. Additionally, those who are newly employed have increased their personal incomes, which means (all else constant) their disposable incomes have also increased, thus fostering further economic expansion.
#
# Generally, the U.S. labor force and levels of employment and unemployment are subject to fluctuations due to seasonal changes in weather, major holidays, and the opening and closing of schools. The Bureau of Labor Statistics (BLS) adjusts the data to offset the seasonal effects to show non-seasonal changes: for example, women's participation in the labor force; or a general decline in the number of employees, a possible indication of a downturn in the economy. To closely examine seasonal and non-seasonal changes, the BLS releases two monthly statistical measures: the seasonally adjusted All Employees: Total Nonfarm (PAYEMS) and All Employees: Total Nonfarm (PAYNSA), which is not seasonally adjusted.
#
# The series comes from the 'Current Employment Statistics (Establishment Survey).'
#
# The source code is: CES0000000001

# %%
df_payroll = getSeries("PAYEMS", description="Total Payroll")

# %% [markdown]
# ---

# %%
import altair as alt

output_per_hour_per_employee =\
    (df_real_output["Real Output per Hour"].resample("1Y").last() / df_payroll["Total Payroll"].resample("1Y").last()).dropna()\
    .rename("SpecificOutput")\
    .reset_index()

ts = alt.Chart(output_per_hour_per_employee).mark_line(color='purple').encode(
    alt.X('date:T'),
    alt.Y('SpecificOutput:Q', axis=alt.Axis(grid=False, title='Specific economic output [$]'))
)

r = alt.Chart(df_recession.reset_index().iloc[-850:]).mark_rule(color='lightgray').encode(
    alt.X('date:T', axis=alt.Axis(title=None, grid=False)),
    alt.Y('Recession:Q', axis=alt.Axis(title=None, ticks=False, labels=False, grid=False)),
    size=alt.value(5)
)

alt.layer(
    r,
    ts
).resolve_scale(
    y='independent'
).properties(
    title="U.S. Real Output per Hour per Employee (Nonfarm) over Time",
    width=800,
    height=500
).interactive()
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ---

# %% [markdown]
# ### U.S. Bureau of Labor Statistics, Hours Worked and Employment Measures for Total U.S. Economy - all workers - June 6, 2018
#
# https://www.bls.gov/lpc/tables.htm
#
# *Units:* Billions of hours worked, Seasonally Adjusted
#
# *Frequency:* Quarterly
#
# Hours-worked series are seasonally-adjusted, and presented in billions. Also note that these quarterly hours series are on an annualized-level basis.

# %%
df_hours = pd.read_excel("https://www.bls.gov/lpc/special_requests/us_total_hrs_emp.xlsx",
                         sheet_name=1, skiprows=7, usecols=[0,10])

df_hours['date'] = df_hours['Worker coverage'].map(lambda s: pd.to_datetime(s[:4] + "-" + str(int(s[-1])*3), format="%Y-%m"))

df_hours = df_hours.set_index('date')

# %% [markdown]
# ---

# %% [markdown]
# #### Calculate "Output per Hour" using data from above BLS primary source

# %%
output_per_hour = (df_us_gdp.GDP / df_hours['employees'].resample("1Y").last()).dropna()

# %%
output_per_hour_per_employee2 =\
    (output_per_hour.resample("1Y").last() / df_payroll["Total Payroll"].resample("1Y").last()).dropna()\
    .rename("SpecificOutput")\
    .reset_index()

ts2 = alt.Chart(output_per_hour_per_employee2).mark_line(color='orange').encode(
    alt.X('date:T'),
    alt.Y('SpecificOutput:Q', axis=alt.Axis(grid=False, title='Specific economic output [$]'))
)

alt.layer(
    r,
    ts2,
    ts
).resolve_scale(
    y='independent'
).properties(
    title="U.S. Real Output per Hour per Employee (Nonfarm) over Time",
    width=800,
    height=500
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ---

# %% [markdown]
# ### U.S. Energy Information Administration, Form EIA-861M (formerly EIA-826) detailed data
#
# https://www.eia.gov/electricity/data/eia861m/index.html#salesrevenue
#
# The Form EIA-861M "Monthly Electric Power Industry Report" collects sales of electricity and associated revenue, each month, from a statistically chosen sample of electric utilities in the United States. The respondents to the Form EIA-861M are chosen from the Form EIA-861, "Annual Electric Power Industry Report." Methodology is based on the "Annual Electric Utility Report." Methodology is based on the "Model-Based Sampling, Inference and Imputation."

# %%
df_elec = pd.read_excel("https://www.eia.gov/electricity/data/eia861m/xls/sales_revenue.xlsx")

levels = []
for c in df_elec.columns:
    if "Unnamed" in c:
        continue
    else:
        for i in range(4):
            levels.append(c.title())
            
categories = [(l, "{} [{}]".format(m, u)) for m, u, l in zip(*df_elec.iloc[0:2].values, levels)]

df_elec.columns = pd.MultiIndex.from_tuples(categories)
df_elec = df_elec.iloc[2:-1]

df_elec = df_elec.rename_axis(["Year", "Month", "State", "Status"])

# %%
df_elec.head(5)
# Out:
#                                        Residential                        \
#                         Revenue [Thousand Dollars] Sales [Megawatthours]
# Year Month State Status
# 1990 1     AK    Final                       17477                181752
#            AL    Final                      123332               2070093
#            AR    Final                       72506               1026320
#            AZ    Final                      109332               1396499
#            CA    Final                      597161               6168009
#
#                                                              \
#                         Customers [Count] Price [Cents/kWh]
# Year Month State Status
# 1990 1     AK    Final                  .              9.62
#            AL    Final                  .              5.96
#            AR    Final                  .              7.06
#            AZ    Final                  .              7.83
# ...

# %% [markdown]
# ---

# %%
df_megawatts = df_elec.groupby(["Year"]).agg(sum)["Total", "Sales [Megawatthours]"][:-1].rename("Megawatt-hours")
df_megawatts.index = pd.to_datetime(df_megawatts.index, format="%Y")

df_megawatts = df_megawatts.reset_index()

cmp = df_megawatts.set_index("Year").resample("1Y").last().join(output_per_hour_per_employee2.set_index("date"))
cmp['year'] = cmp.index.map(lambda d: d.year)
cmp['decade'] = cmp.index.map(lambda v: "19{}0's".format(str(v)[2]) if v.year < 2000 else "20{}0's".format(str(v)[2]))


tsee = alt.Chart(cmp.reset_index()).mark_point(color='blue', size=100).encode(
    alt.X('Megawatt-hours:Q', axis=alt.Axis(grid=False), scale=alt.Scale(zero=False, padding=35)),
    alt.Y('SpecificOutput:Q', scale=alt.Scale(zero=False, padding=15), 
          title='Real output per hour per employee'),
    alt.Color('decade:N'),
    alt.Tooltip(['Year:N', 'Megawatt-hours:Q', 'SpecificOutput:Q'])
).properties(
    title="U.S. Specific Economic Output vs Total Electricity Consumption",
    width=1000,
    height=500
)

text = tsee.mark_text(
    align='left',
    baseline='middle',
    dx=7,
    size=10
).encode(
    text='year:N'
)

tsee  + text
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
cmp = df_megawatts.set_index("Year").resample("1Y").last().join(df_us_gdp)
cmp['year'] = cmp.index.map(lambda d: d.year)
cmp['decade'] = cmp.index.map(lambda v: "19{}0's".format(str(v)[2]) if v.year < 2000 else "20{}0's".format(str(v)[2]))

tegdp = alt.Chart(cmp.reset_index()).mark_point().encode(
    alt.Y('Megawatt-hours', axis=alt.Axis(grid=False), scale=alt.Scale(zero=False, padding=35)),
    alt.X('GDP', axis=alt.Axis(grid=False), scale=alt.Scale(zero=False, padding=35)),
    alt.Color('decade:N'),
).properties(
    title="Total Electricity Consumption vs U.S. Real Gross Domestic Product",
    width=1000,
    height=500
)

text = tegdp.mark_text(
    align='left',
    baseline='middle',
    dx=7,
    size=10
).encode(
    text='year:N'
)

tegdp + text
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ---

# %% [markdown]
# ### U.S. Bureau of Economic Analysis, Real Gross Domestic Product [GDPC1]
#
# https://fred.stlouisfed.org/series/GDPC1
#
# *Units:*  Billions of Chained 2009 Dollars, Seasonally Adjusted Annual Rate
#
# *Frequency:*  Quarterly
#
# BEA Account Code: A191RX
#
# Real gross domestic product is the inflation adjusted value of the goods and services produced by labor and property located in the United States.For more information see the Guide to the National Income and Product Accounts of the United States (NIPA) - (http://www.bea.gov/national/pdf/nipaguid.pdf)

# %%
df_us_gdp = getSeries("GDPC1", description="GDP").resample("1Y").last()

# %% [markdown]
# ---

# %% [markdown]
# ### Board of Governors of the Federal Reserve System (US), M2 Money Stock [M2]
#
# *Units:*  Billions of Dollars, Seasonally Adjusted
#
# *Frequency:*  Weekly, Ending Monday
#
# M2 includes a broader set of financial assets held principally by households. M2 consists of M1 plus: (1) savings deposits (which include money market deposit accounts, or MMDAs); (2) small-denomination time deposits (time deposits in amounts of less than $100,000); and (3) balances in retail money market mutual funds (MMMFs). Seasonally adjusted M2 is computed by summing savings deposits, small-denomination time deposits, and retail MMMFs, each seasonally adjusted separately, and adding this result to seasonally adjusted M1.

# %%
df_m2 = getSeries("M2", description="M2")

# %% [markdown]
# ---

# %%
df_m2_efficiency = (df_m2.M2.resample("1Y").last() /\
                   df_us_gdp.GDP).rename("M2 to GDP")

df_m2_efficiency = df_m2_efficiency.reset_index().dropna()

tsm2gdp = alt.Chart(df_m2_efficiency).mark_line(color='purple').encode(
    alt.X('date:T'),
    alt.Y('M2 to GDP:Q', axis=alt.Axis(grid=False)), #, scale=alt.Scale(zero=False, padding=50))
    alt.Tooltip('round(ext, 2):N')
)

tscpi = alt.Chart(df_cpi.resample("1Y").last().reset_index().iloc[-39:]).mark_line(color='green').encode(
    alt.X('date:T'),
    alt.Y('CPI:Q', axis=alt.Axis(title=None, ticks=False, labels=False, grid=False)),
)

r2 = alt.Chart(df_recession.reset_index().iloc[-350:]).mark_rule(color='lightgray').encode(
    alt.X('date:T', axis=alt.Axis(title=None, grid=False)),
    alt.Y('Recession:Q', axis=alt.Axis(title=None, ticks=False, labels=False, grid=False)),
    size=alt.value(3)
)

alt.layer(
    r2,
    tsm2gdp,
    #tscpi
).resolve_scale(
    y='independent'
).properties(
    title="Dollars of M2 per dollar of Real GDP",
    width=1000,
    height=500
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
